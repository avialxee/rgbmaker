# %%
from rgbmaker.fetch import query
query(name='Avi', position='3C 33.1', radius=0.12, kind='plot')
# Out:
# VLA FIRST (1.4 GHz) not found
# ('success',
#  [{'img1': '...'}],
#  'completed in 31.28. ',
#  [{'NVSS': 'value ranges from -0.0039 to 0.9816'},
#   {'TGSS ADR1': 'value ranges from -0.0169 to 2.5341'},
#   {'VLA FIRST (1.4 GHz)': 'value ranges from 0.0000 to 0.0000'},
#   {'Target center': '01h09m43.60640061s +73d11m56.00312067s'},
#   {'TGSS contour ': '[0.015 0.645 1.275 1.904]'},
#   {'NVSS contour ': '[0.0015 0.2465 0.4915 0.7365]'},
#   {'S_TGSS-1': '17545.1 mJy'},
#   {'S_TGSS_e-1': '1754.8 mJy'},
#   {'S_NVSS-1': '1285.0 mJy'},
#   {'S_NVSS_e-1': '41.4 mJy'},
#   {'S_NVSS-2': '1810.2 mJy'},
#   {'S_NVSS_e-2': '61.0 mJy'}])
